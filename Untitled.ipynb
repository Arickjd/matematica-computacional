# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import io
import plotly.express as px

# %%
path = 'raw_data\INFLUD25-07-07-2025.csv'

df = pd.read_csv(path, sep=";", encoding="latin-1", low_memory=False, on_bad_lines='skip')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\aryck\AppData\Local\Temp\ipykernel_7324\3888286961.py:1: SyntaxWarning: invalid escape sequence '\I'
#   path = 'raw_data\INFLUD25-07-07-2025.csv'

# %%
df
# Out:
#             NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0       31735451969802  2024-12-29        1  2024-12-29        1        SP
# 1       31735516593521  2024-12-29        1  2024-12-29        1        SP
# 2       31735544021940  2024-12-29        1  2024-12-29        1        SP
# 3       31735559043222  2024-12-30        1  2024-12-29        1        AC
# 4       31735560267779  2024-12-30        1  2024-12-29        1        PB
# ...                ...         ...      ...         ...      ...       ...
# 180105  31751862306800  2025-07-06       28  2025-07-06       28        CE
# 180106  31751862570085  2025-07-06       28  2025-07-04       27        CE
# 180107  31751862937578  2025-07-06       28  2025-07-04       27        CE
# 180108  31751863249950  2025-07-06       28  2025-07-05       27        CE
# 180109  31751863911378  2025-07-07       28  2025-07-04       27        SP
#
# ...
